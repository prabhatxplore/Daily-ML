# %%
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
import csv

# %%
with open('data.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    print(csv_reader)
    language_counter = Counter(row['LanguagesWorkedWith'].split(';'))

    for row in csv_reader:
        language_counter.update(row['LanguagesWorkedWith'].split(';'))

languages = []
popularity = []
print(language_counter.most_common(15))
# Out:
# <csv.DictReader object at 0x0000018B7893EF90>
# [('JavaScript', 59220), ('HTML/CSS', 55467), ('SQL', 47545), ('Python', 36444), ('Java', 35917), ('Bash/Shell/PowerShell', 31991), ('C#', 27098), ('PHP', 23030), ('C++', 20524), ('TypeScript', 18523), ('C', 18017), ('Other(s):', 7920), ('Ruby', 7331), ('Go', 7201), ('Assembly', 5833)]
