# %%
from sklearn.datasets import load_diabetes
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import time

# %%
X,y = load_diabetes(return_X_y=True)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (353, 10)
# (353,)

# %%
class S_GDRegressor:
    def __init__(self,learning_rate = 0.01,epochs=100):
        self.lr=learning_rate
        self.epochs=epochs
        self.intercept_= None
        self.coef_ = None

    def fit(self,X_train,y_train):
        self.coef_ =np.ones(X_train.shape[1])
        self.intercept_ = 0

        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                idx = np.random.randint(0,X_train.shape[0])
                y_hat = np.dot(X_train[idx],self.coef_)+self.intercept_

                intercept_d = -2* ( y_train[idx] -y_hat)
                self.intercept_ = self.intercept_ - (self.lr * intercept_d)

                # y_hat = np.dot(X_train[idx],self.coef_)+self.intercept_
                
                coef_d = -2 * np.dot((y_train[idx] - y_hat ),X_train[idx])
                self.coef_ = self.coef_ - (self.lr * coef_d)

        print(self.intercept_ ,self.coef_)

    def predict(self,X_test):
        return np.dot(X_test,self.coef_) +self.intercept_

# %%
sgd = S_GDRegressor(0.1,35)
st = time.time()
sgd.fit(X_train,y_train)
print("\n Difference  = ",time.time()-st)
y_pred = sgd.predict(X_test)
print("\n R2 score =",r2_score(y_test,y_pred))
# Out:
# 161.0218150045032 [ -12.35717075 -183.53377451  532.00612846  308.25700951  -64.33503718
#  -112.85638168 -186.64078539   96.47177416  515.85314315   68.8679324 ]
#
#  Difference  =  0.10948562622070312
#
#  R2 score = 0.4370156820475414

# %%
lr = LinearRegression()
st = time.time()
lr.fit(X_train,y_train)
print("\n Difference  = ",time.time()-st)
print('\n',lr.intercept_,lr.coef_)
l_ypred = lr.predict(X_test)
print('\n R2 score',r2_score(y_test,l_ypred))
# Out:
#  Difference  =  0.01663684844970703
#
#  151.88331005254167 [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
#
#  R2 score 0.4399338661568968

# %%
from sklearn.linear_model import SGDRegressor

# %%
s_reg = SGDRegressor(max_iter=35,learning_rate='constant',eta0=0.1)
st = time.time()
s_reg.fit(X_train,y_train)
print("\n Difference  = ",time.time()-st)

print(s_reg.intercept_,s_reg.coef_)
s_ypred = lr.predict(X_test)
print('\n R2 score',r2_score(y_test,s_ypred))
# Out:
#  Difference  =  0.005564212799072266
# [141.69454289] [   9.26026006 -181.36259825  494.34070002  327.78192961  -38.98276983
#  -117.94249013 -191.31678106   98.72013545  463.9126414    86.08838009]
#
#  R2 score 0.4399338661568968
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_stochastic_gradient.py:1608: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
